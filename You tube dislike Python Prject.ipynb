# %%
import numpy as np    
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Q1

# %%
ytd=pd.read_csv('youtube_dislike_dataset.csv')
ytd
# Out:
#           video_id                                              title
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals  \
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at
# ...

# %%
yt=ytd.copy()

# %%
yt.head()
# Out:
#       video_id                                       title
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals  \
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00  \
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count
# 0     1048888   19515       226           1319  \
# 1    15352638  359277      7479          18729
# ...

# %%
yt.tail()
# Out:
#           video_id                                              title
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...  \
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49  \
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count
# 37417   120408275  2180780     35871          81360  \
# ...

# %% [markdown]
# # Q2

# %%
yt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   video_id         37422 non-null  object
#  1   title            37422 non-null  object
#  2   channel_id       37422 non-null  object
#  3   channel_title    37422 non-null  object
#  4   published_at     37422 non-null  datetime64[ns]
#  5   view_count       37422 non-null  int64
#  6   likes            37422 non-null  int64
#  7   dislikes         37422 non-null  int64
#  8   comment_count    37422 non-null  int64
#  9   tags             37422 non-null  object
#  10  description      37422 non-null  object
#  11  comments         37264 non-null  object
#  12  published_month  37422 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(8)
# memory usage: 3.7+ MB

# %%
yt.dtypes,yt.shape
# Out:
# (video_id         object
#  title            object
#  channel_id       object
#  channel_title    object
#  published_at     object
#  view_count        int64
#  likes             int64
#  dislikes          int64
#  comment_count     int64
#  tags             object
#  description      object
#  comments         object
#  dtype: object,
#  (37422, 12))

# %% [markdown]
# This dataset has the 12 unique columns and 37422 (rows view_count,likes,dislikes  and comment_count)all columns are numeric and all other columns are object datatype

# %% [markdown]
# #   Q3

# %%
yt.columns
# Out:
# Index(['video_id', 'title', 'channel_id', 'channel_title', 'published_at',
#        'view_count', 'likes', 'dislikes', 'comment_count', 'tags',
#        'description', 'comments'],
#       dtype='object')

# %%
yt[yt.duplicated()].sum()
# Out:
# video_id         0
# title            0
# channel_id       0
# channel_title    0
# published_at     0
# view_count       0
# likes            0
# dislikes         0
# comment_count    0
# tags             0
# description      0
# comments         0
# dtype: object

# %% [markdown]
# There is no any duplicated or null or missing values in this dataset % of the missing values is 0%

# %% [markdown]
# # Q4

# %%
yt.describe(include='all')
# Out:
#            video_id  title                channel_id        channel_title
# count         37422  37422                     37422                37422  \
# unique        37422  37113                     10961                10883
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
# mean            NaN    NaN                       NaN                  NaN
# std             NaN    NaN                       NaN                  NaN
# min             NaN    NaN                       NaN                  NaN
# 25%             NaN    NaN                       NaN                  NaN
# 50%             NaN    NaN                       NaN                  NaN
# 75%             NaN    NaN                       NaN                  NaN
# max             NaN    NaN                       NaN                  NaN
#
#                published_at    view_count         likes      dislikes
# ...

# %% [markdown]
# # Q5

# %%
yt['published_at']= pd.to_datetime(yt['published_at'])
yt['published_at']
# Out:
# 0       2021-07-01 10:00:00
# 1       2021-06-10 16:00:00
# 2       2021-09-20 01:03:32
# 3       2021-03-03 10:00:17
# 4       2021-12-07 13:00:00
#                 ...
# 37417   2021-02-12 05:03:49
# 37418   2021-01-16 05:39:05
# 37419   2021-06-02 09:00:10
# 37420   2020-10-20 20:59:30
# 37421   2021-05-23 21:00:31
# Name: published_at, Length: 37422, dtype: datetime64[ns]

# %%
yt.dtypes
# Out:
# video_id                 object
# title                    object
# channel_id               object
# channel_title            object
# published_at     datetime64[ns]
# view_count                int64
# likes                     int64
# dislikes                  int64
# comment_count             int64
# tags                     object
# description              object
# comments                 object
# dtype: object

# %% [markdown]
# #   Q6

# %%
yt['published_at']
# Out:
# 0       2021-07-01 10:00:00
# 1       2021-06-10 16:00:00
# 2       2021-09-20 01:03:32
# 3       2021-03-03 10:00:17
# 4       2021-12-07 13:00:00
#                 ...
# 37417   2021-02-12 05:03:49
# 37418   2021-01-16 05:39:05
# 37419   2021-06-02 09:00:10
# 37420   2020-10-20 20:59:30
# 37421   2021-05-23 21:00:31
# Name: published_at, Length: 37422, dtype: datetime64[ns]

# %%
yt['published_month']=ytd['published_at'].apply(lambda x:x[5:7])
yt['published_month'].unique()
# Out:
# array(['07', '06', '09', '03', '12', '10', '08', '04', '05', '11', '02',
#        '01'], dtype=object)

# %% [markdown]
# # Q7

# %%
yt['published_month']=yt['published_month'].replace('01','Jan')
yt['published_month']=yt['published_month'].replace('02','Feb')
yt['published_month']=yt['published_month'].replace('03','March')
yt['published_month']=yt['published_month'].replace('04','April')
yt['published_month']=yt['published_month'].replace('05','May')
yt['published_month']=yt['published_month'].replace('06','June')
yt['published_month']=yt['published_month'].replace('07','July')
yt['published_month']=yt['published_month'].replace('08','Aug')
yt['published_month']=yt['published_month'].replace('09','Sep')
yt['published_month']=yt['published_month'].replace('10','Oct')
yt['published_month']=yt['published_month'].replace('11','Nov')
yt['published_month']=yt['published_month'].replace('12','Dec')
yt['published_month'].unique()
# Out:
# array(['July', 'June', 'Sep', 'March', 'Dec', 'Oct', 'Aug', 'April',
#        'May', 'Nov', 'Feb', 'Jan'], dtype=object)

# %% [markdown]
# # Q8

# %%
month=pd.pivot_table(data=yt[['published_month','video_id']],index='published_month',aggfunc='count')
month.sort_values(by='video_id',ascending=False)
# Out:
#                  video_id
# published_month
# Oct                  4991
# Sep                  4880
# Nov                  4851
# Aug                  4262
# Dec                  3072
# July                 2340
# June                 2316
# March                2258
# Feb                  2137
# April                2126
# Jan                  2108
# May                  2081

# %% [markdown]
# # Q9

# %%
yt['video_id'].unique().shape[0]  # Count of unique video_id is 37422
# Out:
# 37422

# %%
yt['channel_id'].unique().shape[0]  #Count of unique channel_id is 10961
# Out:
# 10961

# %%
yt['channel_title'].unique().shape[0]  #Count of unique channel_title is 10883
# Out:
# 10883

# %% [markdown]
# # Q10

# %%
cn=pd.pivot_table(data=yt[['channel_title','video_id']],index='channel_title',aggfunc='count')
cn.sort_values(by='video_id',ascending=False).head(10)
# Out:
#                      video_id
# channel_title
# Sky Sports Football       533
# The United Stand          301
# BT Sport                  246
# NBA                       209
# NFL                       162
# WWE                       122
# SSSniperWolf               99
# SSundee                    98
# FORMULA 1                  87
# NHL                        86

# %%
cn.sort_values(by='video_id',ascending=False).tail(10)
# Out:
#                 video_id
# channel_title
# Karchez                1
# Karate Combat          1
# Kaptain Kuba           1
# Kanye West             1
# Kannur kitchen         1
# Kannada Cinema         1
# KanalD                 1
# Kanak News             1
# Kamille Ramos          1
# zoom                   1

# %% [markdown]
# # Q11

# %%
ct_likes=yt[['title','likes']].groupby(by='title').sum()
ct_likes.sort_values(by='likes',ascending=False).head(1)
# Out:
#                                   likes
# title
# BTS () 'Dynamite' Official MV  31837675

# %%
ct_likes.sort_values(by='likes',ascending=False).tail(1)
# Out:
#                                                     likes
# title
# Kim Kardashian's Must-See Moments on "Saturday ...      0

# %% [markdown]
# BTS () 'Dynamite' Official MV has 31837675 likes in youtube whereas  Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News has only 0 likes in youtube

# %% [markdown]
# # Q12

# %%
ct_dislikes=yt[['title','dislikes']].groupby(by='title').sum()
ct_dislikes.sort_values(by='dislikes',ascending=False).head(1)
# Out:
#                                      dislikes
# title
# Cuties | Official Trailer | Netflix   2397733

# %%
ct_dislikes.sort_values(by='dislikes',ascending=False).tail(1)
# Out:
#                                                     dislikes
# title
# Kim Kardashian's Must-See Moments on "Saturday ...         0

# %% [markdown]
# Cuties | Official Trailer | Netflix has the 2397733 dislikes IN Youtube and Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News has 0 dislikes in youtube

# %% [markdown]
# # Q13

# %%
yt[['view_count','dislikes']].plot(x='view_count',y='dislikes',kind='scatter')
plt.show()

# %% [markdown]
# There is no conection between no of views and dislikes, because see the scatter plot here people who have seen the
# videos more dislikes is  less in most of the vedios so there is no effect on no of views and dislikes

# %% [markdown]
# # Q14

# %%
yt[yt['published_month']=='Jan']
# Out:
#           video_id                                              title
# 27     -2Gwm7QfBnE                                    Q&A With Naisha  \
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at
# ...

# %%
yt[yt['published_month']=='Jan'].shape[0]
# Out:
# 2108
